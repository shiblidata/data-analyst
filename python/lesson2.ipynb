# %% [markdown]
# # Python for Data Analytics
# # Pandas (Data table analysis)

# %%
import pandas as pd

data = {
    "Name": ["Rahim", "Karim", "Shibli"],
    "Sales": [100, 200, 150]
}

df = pd.DataFrame(data)

print(df)
# Out:
#      Name  Sales
# 0   Rahim    100
# 1   Karim    200
# 2  Shibli    150
